# %% [markdown]
# <a href="https://colab.research.google.com/github/yafengsong/InCrediblAE/blob/main/IncrediblAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Preliminary Notes
#
# The aim of the InCrediblAE shared task is to build your own custom attack method that will generate adversarial examples to fool a victim classifier. This notebook is intended as an easy way for you to get started.
#
# <br>
#
# ### Using GPU
# It is recommended that you run this notebook with a GPU. To do this, click on "additional connection options" (next to Connect / RAM usage), select "change runtime type", and select a GPU.
#
# <br>
#
# ### (optional) Mounting Google Drive - don't bother with this if running this notebook for first time
# If you will be re-running this notebook many times, it might be convenient to mount your personal google drive. This will allow you to
# 1. load data/victim files quickly rather than re-downloading them with each session
# 2. save output files to a permanent location
#
# Instructions for mounting are in the 'Making your own attack section'.

# %% [markdown]
# # Setup (installing dependencies)

# %%
# !git clone https://github.com/piotrmp/BODEGA
# Out:
# Cloning into 'BODEGA'...
# remote: Enumerating objects: 149, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 149 (delta 79), reused 112 (delta 49), pack-reused 3
# Receiving objects: 100% (149/149), 33.93 KiB | 11.31 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
# !.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %pip install OpenAttack
# %pip install editdistance
# %pip install bert-score
# %pip install git+https://github.com/lucadiliello/bleurt-pytorch.git

# %%
# !git clone https://gitlab.clarin-pl.eu/syntactic-tools/lambo.git
# %pip install ./lambo

# %% [markdown]
# # Downloading victim models and data

# %% [markdown]
# Data and models are downloaded by cloning the [clef2024-checkthat repo](https://gitlab.com/checkthat_lab/clef2024-checkthat-lab.git)
# * alternative [google drive folder link](https://drive.google.com/drive/folders/1ZsDHSejiv4USae0viTsfeLpvqXdeq0FL?usp=sharing)
#
# Data and models are downloaded then moved to /content/BODEGA/incrediblAE_public_release

# %%
# temporary folder for downloading victim models and data
! mkdir /content/clef2024-checkthat-lab

import os, sys
os.chdir("/content/clef2024-checkthat-lab")

! git init
! git remote add -f origin https://gitlab.com/checkthat_lab/clef2024-checkthat-lab.git
! git sparse-checkout init
! git sparse-checkout set "task6/incrediblAE_public_release"
! git pull origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/clef2024-checkthat-lab/.git/
# Updating origin
# remote: Enumerating objects: 548, done.
# remote: Counting objects: 100% (460/460), done.
# remote: Compressing objects: 100% (443/443), done.
# remote: Total 548 (delta 273), reused 43 (delta 15), pack-reused 88
# Receiving objects: 100% (548/548), 9.70 MiB | 10.37 MiB/s, done.
# Resolving deltas: 100% (286/286), done.
# From https://gitlab.com/checkthat_lab/clef2024-checkthat-lab
#  * [new branch]      FHaouari-main-patch-26640 -> origin/FHaouari-main-patch-26640
#  * [new branch]      FHaouari-main-patch-34250 -> origin/FHaouari-main-patch-34250
#  * [new branch]      FHaouari-main-patch-81200 -> origin/FHaouari-main-patch-81200
#  * [new branch]      main                      -> origin/main
# From https://gitlab.com/checkthat_lab/clef2024-checkthat-lab
#  * branch            main       -> FETCH_HEAD
# Filtering content: 100% (24/24), 2.37 GiB | 49.85 MiB/s, done.

# %%
# move downloaded files to /content/BODEGA
! mv /content/clef2024-checkthat-lab/task6/incrediblAE_public_release /content/BODEGA/incrediblAE_public_release

# %% [markdown]
# Misc set up

# %%
#folder for storing results of attack method
! mkdir /content/BODEGA/outputs

#code below assumes we are working from the BODEGA repo
os.chdir("/content/BODEGA")

# %% [markdown]
# # Making your own attack

# %% [markdown]
# ## Imports

# %%
import gc
import os
import pathlib
import sys
import time
import random
import numpy as np

import OpenAttack
import torch
import datasets
from datasets import Dataset

from OpenAttack.tags import Tag
from OpenAttack.text_process.tokenizer import PunctTokenizer

from metrics.BODEGAScore import BODEGAScore
from utils.data_mappings import dataset_mapping, dataset_mapping_pairs, SEPARATOR_CHAR
from utils.no_ssl_verify import no_ssl_verify
from victims.bert import VictimBERT, readfromfile_generator
from victims.bilstm import VictimBiLSTM
from victims.caching import VictimCache
from victims.unk_fix_wrapper import UNK_TEXT

#imports for BodegaAttackEval wrapper
from typing import Any, Dict, Generator, Iterable, List, Optional, Union
from tqdm import tqdm
from OpenAttack.utils import visualizer, result_visualizer, get_language, language_by_name
from OpenAttack.tags import *

# %%
using_mounted_drive = False
print('Cuda device available', torch.cuda.is_available())
# Out:
# Cuda device available True

# %% [markdown]
# ## (do not change) Wrapper for producing submission file

# %%
class BodegaAttackEval(OpenAttack.AttackEval):
  '''
  wrapper for OpenAttack.AttackEval to produce a submission.tsv file for shared task evaluation

  To perform evaluation, we use a new method: eval_and_save_tsv() rather than the usual AttackEval.eval()
  submission.tsv file consists of 4 columns for each sample in attack set: succeeded, num_queries, original_text and modified text (newlines are escaped)

  '''
  def eval_and_save_tsv(self, dataset: Iterable[Dict[str, Any]], total_len : Optional[int] = None, visualize : bool = False, progress_bar : bool = False, num_workers : int = 0, chunk_size : Optional[int] = None, tsv_file_path: Optional[os.PathLike] = None):
      """
      Evaluation function of `AttackEval`.

      Args:
          dataset: An iterable dataset.
          total_len: Total length of dataset (will be used if dataset doesn't has a `__len__` attribute).
          visualize: Display a pretty result for each data in the dataset.
          progress_bar: Display a progress bar if `True`.
          num_workers: The number of processes running the attack algorithm. Default: 0 (running on the main process).
          chunk_size: Processing pool trunks size.

          tsv_file_path: path to save submission tsv

      Returns:
          A dict of attack evaluation summaries.

      """


      if hasattr(dataset, "__len__"):
          total_len = len(dataset)

      def tqdm_writer(x):
          return tqdm.write(x, end="")

      if progress_bar:
          result_iterator = tqdm(self.ieval(dataset, num_workers, chunk_size), total=total_len)
      else:
          result_iterator = self.ieval(dataset, num_workers, chunk_size)

      total_result = {}
      total_result_cnt = {}
      total_inst = 0
      success_inst = 0

      #list for tsv
      x_orig_list = []
      x_adv_list = []
      num_queries_list = []
      succeed_list = []

      # Begin for
      for i, res in enumerate(result_iterator):
          total_inst += 1
          success_inst += int(res["success"])

          if TAG_Classification in self.victim.TAGS:
              x_orig = res["data"]["x"]
              if res["success"]:
                  x_adv = res["result"]
                  if Tag("get_prob", "victim") in self.victim.TAGS:
                      self.victim.set_context(res["data"], None)
                      try:
                          probs = self.victim.get_prob([x_orig, x_adv])
                      finally:
                          self.victim.clear_context()
                      y_orig = probs[0]
                      y_adv = probs[1]
                  elif Tag("get_pred", "victim") in self.victim.TAGS:
                      self.victim.set_context(res["data"], None)
                      try:
                          preds = self.victim.get_pred([x_orig, x_adv])
                      finally:
                          self.victim.clear_context()
                      y_orig = int(preds[0])
                      y_adv = int(preds[1])
                  else:
                      raise RuntimeError("Invalid victim model")
              else:
                  y_adv = None
                  x_adv = None
                  if Tag("get_prob", "victim") in self.victim.TAGS:
                      self.victim.set_context(res["data"], None)
                      try:
                          probs = self.victim.get_prob([x_orig])
                      finally:
                          self.victim.clear_context()
                      y_orig = probs[0]
                  elif Tag("get_pred", "victim") in self.victim.TAGS:
                      self.victim.set_context(res["data"], None)
                      try:
                          preds = self.victim.get_pred([x_orig])
                      finally:
                          self.victim.clear_context()
                      y_orig = int(preds[0])
                  else:
                      raise RuntimeError("Invalid victim model")
              info = res["metrics"]
              info["Succeed"] = res["success"]
              if visualize:
                  if progress_bar:
                      visualizer(i + 1, x_orig, y_orig, x_adv, y_adv, info, tqdm_writer, self.tokenizer)
                  else:
                      visualizer(i + 1, x_orig, y_orig, x_adv, y_adv, info, sys.stdout.write, self.tokenizer)

              #list for tsv
              succeed_list.append(res["success"])
              num_queries_list.append(res["metrics"]["Victim Model Queries"])
              x_orig_list.append(x_orig)

              if res["success"]:
                x_adv_list.append(x_adv)
              else:
                x_adv_list.append("ATTACK_UNSUCCESSFUL")



          for kw, val in res["metrics"].items():
              if val is None:
                  continue

              if kw not in total_result_cnt:
                  total_result_cnt[kw] = 0
                  total_result[kw] = 0
              total_result_cnt[kw] += 1
              total_result[kw] += float(val)
      # End for

      summary = {}
      summary["Total Attacked Instances"] = total_inst
      summary["Successful Instances"] = success_inst
      summary["Attack Success Rate"] = success_inst / total_inst
      for kw in total_result_cnt.keys():
          if kw in ["Succeed"]:
              continue
          if kw in ["Query Exceeded"]:
              summary["Total " + kw] = total_result[kw]
          else:
              summary["Avg. " + kw] = total_result[kw] / total_result_cnt[kw]

      if visualize:
          result_visualizer(summary, sys.stdout.write)


      #saving tsv
      if tsv_file_path is not None:
        with open(tsv_file_path, 'w') as f:
          f.write('succeeded' + '\t' + 'num_queries' + '\t' + 'original_text' + '\t' + 'modified_text' + '\t'+ '\n') #header
          for success, num_queries, x_orig, x_adv in zip(succeed_list, num_queries_list, x_orig_list, x_adv_list):
            escaped_x_orig = x_orig.replace('\n', '\\n') #escaping newlines
            escaped_x_adv = x_adv.replace('\n', '\\n')
            f.write(str(success) + '\t' + str(num_queries) + '\t' + escaped_x_orig + '\t' + escaped_x_adv + '\t'+ '\n')

      return summary

# %% [markdown]
# ## (optional) Mounting Google Drive

# %% [markdown]
# Steps to use mounted google drive:
# 1. create a folder in your local google drive (e.g. `incrediblAE_public_release`)
# 2. download all directories from the download link (see [Download section above](https://colab.research.google.com/drive/1juHWIL44z8O3C5wDAE45vzlJgX51KI5D?authuser=3#scrollTo=eVVE2-64rKuS&line=3&uniqifier=1://)) and upload them to your google drive folder
# 3. create an empty subdirectory called `outputs` (`incredibleAE_public_release/outputs/`)
#
# At this point, your google drive folder should have 6 subdirectories (C19, FC, HN, PR2, RD, and outputs)
# 4. uncomment code below, replacing path_to_mounted_dir with path to your folder (e.g. `/content/drive/My Drive/incrediblAE_public_release`)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# using_mounted_drive = True
# path_to_mounted_folder = '/content/drive/My Drive/incrediblAE_public_release'

# %% [markdown]
# You can also comment out the !gdown command in Downloading section, so the notebook doesn't redownload data each time you run it.

# %% [markdown]
# ## Making custom attacker (token shuffler)

# %% [markdown]
# Here's an example of how to create a custom attack method.
# Your attacker will need to subclass `OpenAttack.attackers.ClassificationAttacker`
#
# (See also OpenAttack framework docs: https://openattack.readthedocs.io/en/latest/)

# %%
'''
This example code shows how to design a customized attack model (that shuffles the tokens in the original sentence).
Taken from https://github.com/thunlp/OpenAttack/blob/master/examples/custom_attacker.py
'''

class MyAttacker(OpenAttack.attackers.ClassificationAttacker):
    @property
    def TAGS(self):
        # returns tags can help OpenAttack to check your parameters automatically
        return { self.lang_tag, Tag("get_pred", "victim") }

    def __init__(self, tokenizer = None):
        if tokenizer is None:
            tokenizer = PunctTokenizer()
        self.tokenizer = tokenizer
        self.lang_tag = OpenAttack.utils.get_language([self.tokenizer])
        # We add parameter ``processor`` to specify the :py:class:`.TextProcessor` which is used for tokenization and detokenization.
        # By default, :py:class:`.DefaultTextProcessor` is used.

    def attack(self, victim, input_, goal):
        # Generate a potential adversarial example
        x_new = self.tokenizer.detokenize(
            self.swap( self.tokenizer.tokenize(input_, pos_tagging=False) )
        )

        # Get the predictions of victim classifier
        y_new = victim.get_pred([ x_new ])

        # Check for attack goal
        if goal.check(x_new, y_new):
            return x_new
        # Failed
        return None

    def swap(self, sentence):
        # Shuffle tokens to generate a potential adversarial example
        random.shuffle(sentence)

        # Return the potential adversarial example
        return sentence

# %% [markdown]
# ## Testing your attack

# %% [markdown]
# The code below will test MyAttacker (above) on the victim classifier, compute BODEGA score, and output results to /content/BODEGA/outputs.
#
# WARNING: files in default output directory (/content/BODGEa/outputs) do not persist after you disconnect from the colab runtime session. To keep them, you can either:
#
# 1. download them manually or
# 2. set `out_dir` to a mounted Google Drive directory (will automatically save files to your google drive)

# %% [markdown]
# ### Choose task + victim classifier

# %%
# determinism
random.seed(10)
torch.manual_seed(10)
np.random.seed(0)

# Change these variables to what you want
task = 'PR2' # PR2, HN, FC, RD, C19
victim_model = 'BERT' # BERT or BiLSTM
using_custom_attacker = True # change to False if you want to test out OpenAttack's pre-implemented attackers (e.g. BERTattack)
attack = 'custom' # if using custom attack, this name can be whatever you want. If using pre-implemented attack, set to name of attacker ('BERTattack')

# misc variables - no need to change
targeted = False # this shared task evaluates performance in an untargeted scenario
visualize_adv_examples = True # prints adversarial samples as they are generated, showing the difference between original
using_first_n_samples = False # used when you want to evaluate on a subset of the full eval set.
first_n_samples = 20

# %% [markdown]
# ### Run to evaluate attacker

# %%
if using_mounted_drive:
    data_path =  pathlib.Path(f"{path_to_mounted_folder}/{task}")
    model_path = pathlib.Path(f"{path_to_mounted_folder}/{task}/{victim_model}-512.pth")
    out_dir = pathlib.Path(f"{path_to_mounted_folder}/outputs")

else:
  data_path =  pathlib.Path(f"/content/BODEGA/incrediblAE_public_release/{task}")
  model_path = pathlib.Path(f"/content/BODEGA/incrediblAE_public_release/{task}/{victim_model}-512.pth")
  out_dir = pathlib.Path("/content/BODEGA/outputs")



RESULTS_FILE_NAME = 'results_' + task + '_' + str(targeted) + '_' + attack + '_' + victim_model + '.txt' #stores BODEGA metrics
SUBMISSION_FILE_NAME = 'submission_' + task + '_' + str(targeted) + '_' + attack + '_' + victim_model + '.tsv' #stores original and modified text, to be submitted to shared task organizers

results_path = out_dir / RESULTS_FILE_NAME if out_dir else None
submission_path = out_dir / SUBMISSION_FILE_NAME if out_dir else None

if out_dir:
    if (out_dir / RESULTS_FILE_NAME).exists():
      print(f"Existing results file found. This script will overwrite previous file: {str(results_path)}")
    if submission_path.exists():
      print(f"Existing submission file found. This script will overwrite previous file: {str(submission_path)}")




# Prepare task data
with_pairs = (task == 'FC' or task == 'C19')

# Choose device
print("Setting up the device...")

using_TF = (attack in ['TextFooler', 'BAE'])
if using_TF:
    # Disable GPU usage by TF to avoid memory conflicts
    import tensorflow as tf

    tf.config.set_visible_devices(devices=[], device_type='GPU')

if torch.cuda.is_available():
    print('using GPU')
    victim_device = torch.device("cuda")
    attacker_device = torch.device("cuda")
else:
    victim_device = torch.device("cpu")
    attacker_device = torch.device('cpu')

# Prepare victim
print("Loading up victim model...")
if victim_model == 'BERT':
    victim = VictimCache(model_path, VictimBERT(model_path, task, victim_device))
elif victim_model == 'BiLSTM':
    victim = VictimCache(model_path, VictimBiLSTM(model_path, task, victim_device))

# Load data
print("Loading data...")
test_dataset = Dataset.from_generator(readfromfile_generator,
                                      gen_kwargs={'subset': 'attack', 'dir': data_path, 'trim_text': True,
                                                  'with_pairs': with_pairs})
if not with_pairs:
    dataset = test_dataset.map(dataset_mapping)
    dataset = dataset.remove_columns(["text"])
else:
    dataset = test_dataset.map(dataset_mapping_pairs)
    dataset = dataset.remove_columns(["text1", "text2"])

dataset = dataset.remove_columns(["fake"])

# Filter data
if using_first_n_samples:
  dataset = dataset.select(range(first_n_samples))

if targeted:
    dataset = [inst for inst in dataset if inst["y"] == 1 and victim.get_pred([inst["x"]])[0] == inst["y"]]

print("Subset size: " + str(len(dataset)))

# Prepare attack
print("Setting up the attacker...")

# Necessary to bypass the outdated SSL certifiacte on the OpenAttack servers
with no_ssl_verify():
  if using_custom_attacker:
    attacker = MyAttacker()
  else:
    filter_words = OpenAttack.attack_assist.filter_words.get_default_filter_words('english') + [SEPARATOR_CHAR]
    if attack == 'PWWS':
        attacker = OpenAttack.attackers.PWWSAttacker(token_unk=UNK_TEXT, lang='english', filter_words=filter_words)
    elif attack == 'SCPN':
        os.environ["TOKENIZERS_PARALLELISM"] = "false"
        attacker = OpenAttack.attackers.SCPNAttacker(device=attacker_device)
    elif attack == 'TextFooler':
        attacker = OpenAttack.attackers.TextFoolerAttacker(token_unk=UNK_TEXT, lang='english',
                                                           filter_words=filter_words)
    elif attack == 'DeepWordBug':
        attacker = OpenAttack.attackers.DeepWordBugAttacker(token_unk=UNK_TEXT)
    elif attack == 'VIPER':
        attacker = OpenAttack.attackers.VIPERAttacker()
    elif attack == 'GAN':
        attacker = OpenAttack.attackers.GANAttacker()
    elif attack == 'Genetic':
        attacker = OpenAttack.attackers.GeneticAttacker(lang='english', filter_words=filter_words)
    elif attack == 'PSO':
        attacker = OpenAttack.attackers.PSOAttacker(lang='english', filter_words=filter_words)
    elif attack == 'BERTattack':
        attacker = OpenAttack.attackers.BERTAttacker(filter_words=filter_words, use_bpe=False, device=attacker_device)
    elif attack == 'BAE':
        attacker = OpenAttack.attackers.BAEAttacker(device=attacker_device, filter_words=filter_words)
    else:
        attacker = None

# Run the attack
print("Evaluating the attack...")
RAW_FILE_NAME = 'raw_' + task + '_' + str(targeted) + '_' + attack + '_' + victim_model + '.tsv'
raw_path = out_dir / RAW_FILE_NAME if out_dir else None

scorer = BODEGAScore(victim_device, task, align_sentences=True, semantic_scorer="BLEURT", raw_path = raw_path)
with no_ssl_verify():
    attack_eval = BodegaAttackEval(attacker, victim, language='english', metrics=[
        scorer  # , OpenAttack.metric.EditDistance()
    ])
    start = time.time()
    summary = attack_eval.eval_and_save_tsv(dataset, visualize=visualize_adv_examples, progress_bar=False, tsv_file_path = submission_path)
    end = time.time()
attack_time = end - start
attacker = None

# Remove unused stuff
victim.finalise()
del victim
gc.collect()
torch.cuda.empty_cache()
if "TOKENIZERS_PARALLELISM" in os.environ:
    del os.environ["TOKENIZERS_PARALLELISM"]

# Evaluate
start = time.time()
score_success, score_semantic, score_character, score_BODEGA= scorer.compute()
end = time.time()
evaluate_time = end - start

# Print results
print("Subset size: " + str(len(dataset)))
print("Success score: " + str(score_success))
print("Semantic score: " + str(score_semantic))
print("Character score: " + str(score_character))
print("BODEGA score: " + str(score_BODEGA))
print("Queries per example: " + str(summary['Avg. Victim Model Queries']))
print("Total attack time: " + str(attack_time))
print("Time per example: " + str((attack_time) / len(dataset)))
print("Total evaluation time: " + str(evaluate_time))

if out_dir:
  with open(results_path, 'w') as f:
      f.write("Subset size: " + str(len(dataset)) + '\n')
      f.write("Success score: " + str(score_success) + '\n')
      f.write("Semantic score: " + str(score_semantic) + '\n')
      f.write("Character score: " + str(score_character) + '\n')
      f.write("BODEGA score: " + str(score_BODEGA) + '\n')
      f.write("Queries per example: " + str(summary['Avg. Victim Model Queries']) + '\n')
      f.write("Total attack time: " + str(end - start) + '\n')
      f.write("Time per example: " + str((end - start) / len(dataset)) + '\n')
      f.write("Total evaluation time: " + str(evaluate_time) + '\n')

  print('-')
  print('Bodega metrics saved to', results_path)
  print('Submission file saved to', submission_path)
# Out:
# Setting up the device...
# using GPU
# Loading up victim model...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Victim caching: file not found, starting from scratch...
# Loading data...
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/416 [00:00<?, ? examples/s]
# Subset size: 416
# Setting up the attacker...
# Downloading TProcess.NLTKSentTokenizer: 100%|██████████| 162k/162k [00:00<00:00, 374kB/s]
# Downloading TProcess.NLTKPerceptronPosTagger: 100%|██████████| 2.53M/2.53M [00:00<00:00, 2.87MB/s]
# Evaluating the attack...
# config.json:   0%|          | 0.00/837 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.30G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BleurtSPTokenizer'.
# The class this function is called from is 'BertTokenizer'.
# spm.model:   0%|          | 0.00/4.70M [00:00<?, ?B/s]
# Sample: 1 =====================================================================
# Label: 0 (98.07%) --> 1 (93.75%)            |
#                                             |
# “    The U       .    S   .                 |
# that all Saucier free are clearly           |
#                                             |
# Constitution clearly states that            |
# S            U       by     the             |
#                                             | Running Time:            0.0017483
# all         citizens are born with          | Query Exceeded:          no
# persecution citizens .   to   government    | Victim Model Queries:    3
#                                             | BODEGA Score:            (later)
# inalienable rights to   be free   from      | Succeed:                 yes
# from        rights said .  states ,”        |
#                                             |
# persecution by           the government     |
# with        Constitution “   .              |
#                                             |
# ,”          Saucier said .                  |
# inalienable born    The  be                 |
#                                             |
# Sample: 2 =====================================================================
# Label: 0 (97.23%) --> Failed!               |
#                                             | Running Time:            0.0001435
#                                             | Query Exceeded:          no
# It was also apparently evidence of the      | Victim Model Queries:    2
# paper ’ s clickbait tendencies :            | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 3 =====================================================================
# Label: 0 (99.95%) --> Failed!               |
#                                             | Running Time:            0.0001473
# Ebola virus disease , formerly known as     | Query Exceeded:          no
# Ebola haemorrhagic fever , is a severe ,    | Victim Model Queries:    2
# often fatal illness in humans .             | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 4 =====================================================================
# Label: 0 (99.97%) --> Failed!               |
#                                             | Running Time:            0.0001838
# So flagrant was Ricca ’ s behaviour that it | Query Exceeded:          no
# took intervention by Uruguay ’ s nuncio to  | Victim Model Queries:    2
# have him removed .                          | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 5 =====================================================================
# Label: 1 (99.90%) --> Failed!               |
#                                             | Running Time:            0.0001378
#                                             | Query Exceeded:          no
# The data was completely out of [ members ’] | Victim Model Queries:    2
# possession .”                               | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 6 =====================================================================
# Label: 1 (95.74%) --> Failed!               |
#                                             |
# Beyond pressuring our allies , consider     |
# these specific steps President Trump has    |
# taken against Russia : Where President      | Running Time:            0.0002573
# Obama refused to provide serious weapons to | Query Exceeded:          no
# the Ukrainians to help them defend          | Victim Model Queries:    2
# themselves ( his response was weakness on a | BODEGA Score:            (later)
# pathetic scale ), President Trump has       | Succeed:                 no
# approved the sale of offensive weapons to   |
# enable the Ukrainians to increase the cost  |
# of Russian aggression .                     |
#                                             |
# Sample: 7 =====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0002058
# The Israelis and Saudi royals want the U .  | Query Exceeded:          no
# S . to keep Iran from securing a land       | Victim Model Queries:    2
# bridge from Tehran to Damascus to Lebanon . | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 8 =====================================================================
# Label: 1 (95.04%) --> Failed!               |
#                                             | Running Time:            0.0001512
# His opponents in the Senate have            | Query Exceeded:          no
# transformed their “ advise and consent ”    | Victim Model Queries:    2
# function into a campaign of no - holds      | BODEGA Score:            (later)
# barred character assassination .            | Succeed:                 no
#                                             |
# Sample: 9 =====================================================================
# Label: 0 (99.23%) --> Failed!               |
#                                             | Running Time:            0.0001473
#                                             | Query Exceeded:          no
# This man whom we had believed a “ champion  | Victim Model Queries:    2
# of orthodoxy ,” whom we thought we knew .   | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 10 ====================================================================
# Label: 1 (92.65%) --> Failed!               |
#                                             | Running Time:            0.0001273
# It will also help the monastery become ‘    | Query Exceeded:          no
# less viable ’ because by the time anyone    | Victim Model Queries:    2
# younger is professed , the others will be   | BODEGA Score:            (later)
# dead .”                                     | Succeed:                 no
#                                             |
# Sample: 11 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0001519
#                                             | Query Exceeded:          no
# The main difference between asteroids and   | Victim Model Queries:    2
# comets is their composition .               | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 12 ====================================================================
# Label: 0 (96.96%) --> Failed!               |
#                                             |
# She issued the warnings in a speech at the  |
# Foundation for Defense of Democracies think | Running Time:            0.0002170
# tank as Iran announced Tuesday that it was  | Query Exceeded:          no
# formally moving ahead with preparations to  | Victim Model Queries:    2
# increase its nuclear enrichment capacities  | BODEGA Score:            (later)
# — the sharpest response to date by the      | Succeed:                 no
# Islamic republic to Mr . Trump ’ s pullout  |
# from the nuclear accord .                   |
#                                             |
# Sample: 13 ====================================================================
# Label: 1 (56.27%) --> Failed!               |
#                                             | Running Time:            0.0001068
#                                             | Query Exceeded:          no
# Not a one .                                 | Victim Model Queries:    2
#                                             | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 14 ====================================================================
# Label: 0 (99.43%) --> 1 (98.26%)            |
#                                             |
# At its  close   the number of    murders    |
#    than murders the course being six        |
#                                             |
# had    more    than doubled ,    and in     |
# number more of than ,       were had in     |
#                                             | Running Time:            0.0001481
# any   six month   period ,   more           | Query Exceeded:          no
# whole its century any    and close          | Victim Model Queries:    3
#                                             | BODEGA Score:            (later)
# Americans were  being  murdered than those  | Succeed:                 yes
# executed  month period murdered At   of     |
#                                             |
# executed during the whole course of         |
# ,        during .   more  the    the        |
#                                             |
# the     century   .                         |
# doubled Americans those                     |
#                                             |
# Sample: 15 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0002036
# TRAVIS AIR FORCE BASE , Calif . ( KGO ) — A | Query Exceeded:          no
# man who drove into Travis AFB has been      | Victim Model Queries:    2
# identified as 51 - year - old Hafiz Kazi ,  | BODEGA Score:            (later)
# two sources with knowledge of the probe     | Succeed:                 no
# tell ABC News .                             |
#                                             |
# Sample: 16 ====================================================================
# Label: 0 (99.85%) --> Failed!               |
#                                             | Running Time:            0.0001025
# The anti - Israel leftists at the AJHS are  | Query Exceeded:          no
# clearly not leaving their politics at home  | Victim Model Queries:    2
# .                                           | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 17 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             |
# Over the past few weeks , the active - duty | Running Time:            0.0001428
# servicemen deployed under Operation         | Query Exceeded:          no
# Faithful Patriot have mainly been erecting  | Victim Model Queries:    2
# barbed - wire fences along the border in    | BODEGA Score:            (later)
# Texas , California and Arizona , as well as | Succeed:                 no
# building shelter accommodation for customs  |
# and border protection staff .               |
#                                             |
# Sample: 18 ====================================================================
# Label: 1 (61.21%) --> Failed!               |
#                                             |
# But more significantly , it bolsters the    | Running Time:            0.0001416
# otherwise risible claim that Assange is not | Query Exceeded:          no
# a publisher – and thereby entitled to the   | Victim Model Queries:    2
# protections of a free press , as enjoyed by | BODEGA Score:            (later)
# the Guardian or the New York Times – but    | Succeed:                 no
# the head of an organisation engaged in      |
# espionage for a foreign power .             |
#                                             |
# Sample: 19 ====================================================================
# Label: 0 (99.95%) --> 1 (98.34%)            |
#                                             |
# This could be  a  great mercy for           |
# a    well  for of might them  protection    |
#                                             |
# them    as well as        for society ,     |
# society as ,    expiation and terms   .     | Running Time:            0.0001431
#                                             | Query Exceeded:          no
# both  in   terms  of   expiation and        | Victim Model Queries:    3
# could they future This both      crimes     | BODEGA Score:            (later)
#                                             | Succeed:                 yes
# protection from any future crimes they      |
# mercy      have as  great  be     from      |
#                                             |
# might have        perpetrated .             |
# for   perpetrated any         in            |
#                                             |
# Sample: 20 ====================================================================
# Label: 1 (87.87%) --> 0 (99.82%)            |
#                                             | Running Time:            0.0001478
# The  #       StephenPaddock suicide note    | Query Exceeded:          no
# that suicide StephenPaddock govt    The     | Victim Model Queries:    3
#                                             | BODEGA Score:            (later)
# that the  govt .                            | Succeed:                 yes
# #    note the  .                            |
#                                             |
# Sample: 21 ====================================================================
# Label: 1 (99.97%) --> Failed!               |
#                                             |
# By inviting people like Shafayat Mohamed ,  |
# an avowed enemy of the gay community , and  | Running Time:            0.0001426
# Wilfredo Ruiz , whose group promotes white  | Query Exceeded:          no
# supremacists , to participate in its        | Victim Model Queries:    2
# functions , the Democratic Party has        | BODEGA Score:            (later)
# effectively revealed its disregard for the  | Succeed:                 no
# concerns of those it disingenuously claims  |
# to advocate for and protect .               |
#                                             |
# Sample: 22 ====================================================================
# Label: 1 (94.07%) --> 0 (99.36%)            |
#                                             |
# The aim was                 to silence and  |
#     aim was criminalise and .  silence to   | Running Time:            0.0001578
#                                             | Query Exceeded:          no
# criminalise WikiLeaks and its editor and    | Victim Model Queries:    3
# publisher   its       and and editor        | BODEGA Score:            (later)
#                                             | Succeed:                 yes
# publisher .                                 |
# The       WikiLeaks                         |
#                                             |
# Sample: 23 ====================================================================
# Label: 1 (97.63%) --> Failed!               |
#                                             | Running Time:            0.0001388
# One of the things I ’ ve been saying is a   | Query Exceeded:          no
# blessing in disguise , and an enormous      | Victim Model Queries:    2
# relief , about the Bergoglian era is that   | BODEGA Score:            (later)
# we can finally leave behind us the absurd   | Succeed:                 no
# situation of the Wojtyla / Ratzinger era .  |
#                                             |
# Sample: 24 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0001056
#                                             | Query Exceeded:          no
# McMaster is remaking it to match Jeb Bush ’ | Victim Model Queries:    2
# s vision .”                                 | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 25 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             |
# [ Investigators ] also discovered that the  | Running Time:            0.0001423
# server in question [ the replacement server | Query Exceeded:          no
# ] was still operating under the employee ’  | Victim Model Queries:    2
# s control , contrary to the explicit        | BODEGA Score:            (later)
# instructions of the former chairman to turn | Succeed:                 no
# over all equipment and fully cooperate with |
# the inquiry and investigation .             |
#                                             |
# Sample: 26 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             |
# Let ’ s assume for the sake of argument     | Running Time:            0.0001407
# that the normal burden on the prosecution   | Query Exceeded:          no
# in a criminal case - to prove the accused ’ | Victim Model Queries:    2
# s guilt beyond a reasonable doubt - is not  | BODEGA Score:            (later)
# applicable regarding the charge against     | Succeed:                 no
# Judge Kavanaugh since he is not a defendant |
# in a criminal trial .                       |
#                                             |
# Sample: 27 ====================================================================
# Label: 1 (99.85%) --> 0 (89.37%)            |
#                                             | Running Time:            0.0001512
# Needless to say   ,        the      Never   | Query Exceeded:          no
# the      to Never Trumpers Needless .       | Victim Model Queries:    3
#                                             | BODEGA Score:            (later)
# Trumpers are .                              | Succeed:                 yes
# ,        are say                            |
#                                             |
# Sample: 28 ====================================================================
# Label: 1 (50.01%) --> 0 (62.93%)            |
#                                             |
#     According to one    widely held         |
# has be        be one in and    impractical  |
#                                             |
# opinion ,      the   death penalty has      |
# to      should crime no    to      ,        | Running Time:            0.0001402
#                                             | Query Exceeded:          no
# proved    to      be     no      effective  | Victim Model Queries:    3
# discarded opinion proved penalty effective  | BODEGA Score:            (later)
#                                             | Succeed:                 yes
# deterrent to crime  in  any case , and      |
# deterrent    widely the ,   case   any      |
#                                             |
# should be discarded as   impractical .      |
# as     to .         held According   death  |
#                                             |
# Sample: 29 ====================================================================
# Label: 1 (78.18%) --> 0 (76.31%)            |
#                                             | Running Time:            0.0001299
#                                             | Query Exceeded:          no
# Apparently not .                            | Victim Model Queries:    3
# Apparently .   not                          | BODEGA Score:            (later)
#                                             | Succeed:                 yes
#                                             |
# Sample: 30 ====================================================================
# Label: 0 (99.97%) --> Failed!               |
#                                             | Running Time:            0.0001624
#                                             | Query Exceeded:          no
# Can we think of any other names who were    | Victim Model Queries:    2
# corrected even to this degree ?             | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 31 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0001147
#                                             | Query Exceeded:          no
# You can see her photographed at the         | Victim Model Queries:    2
# American Task Force of Palestine gala .     | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 32 ====================================================================
# Label: 0 (99.91%) --> Failed!               |
#                                             | Running Time:            0.0002062
#                                             | Query Exceeded:          no
# St . Valentine is known as the saint of     | Victim Model Queries:    2
# friendship and of love .                    | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 33 ====================================================================
# Label: 0 (99.94%) --> Failed!               |
#                                             | Running Time:            0.0001919
# The exact same aircraft and apparent        | Query Exceeded:          no
# muzzles flashes can also be seen in the     | Victim Model Queries:    2
# Arch Angel Studios “ First Shots ” video    | BODEGA Score:            (later)
# which was posted to YouTube on Oct . 2 ,    | Succeed:                 no
# just one day after the shooting .           |
#                                             |
# Sample: 34 ====================================================================
# Label: 1 (92.89%) --> Failed!               |
#                                             | Running Time:            0.0001903
# It may seem like a moment to enjoy , seeing | Query Exceeded:          no
# the apparently unbreachable shell of papal  | Victim Model Queries:    2
# teflon finally cracking , but in reality    | BODEGA Score:            (later)
# this situation is potentially very harmful  | Succeed:                 no
# for souls in the long run .                 |
#                                             |
# Sample: 35 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0001233
# If the Daily is committed to systematically | Query Exceeded:          no
# excluding the voices of an ethno -          | Victim Model Queries:    2
# religious community on campus , then it     | BODEGA Score:            (later)
# cannot continue to receive automatic        | Succeed:                 no
# student funding , as it does now .          |
#                                             |
# Sample: 36 ====================================================================
# Label: 0 (99.97%) --> Failed!               |
#                                             | Running Time:            0.0001450
# All of the critics of AL are wrong — every  | Query Exceeded:          no
# one of them !— because , you see , the      | Victim Model Queries:    2
# original Latin text does not say what the   | BODEGA Score:            (later)
# English text does .                         | Succeed:                 no
#                                             |
# Sample: 37 ====================================================================
# Label: 0 (99.98%) --> Failed!               |
#                                             | Running Time:            0.0001173
#                                             | Query Exceeded:          no
# Dina Habib Powell is a deep part of the     | Victim Model Queries:    2
# Republican establishment .                  | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 38 ====================================================================
# Label: 1 (99.97%) --> Failed!               |
#                                             | Running Time:            0.0001409
# That black - hearted Presbyterian bigot     | Query Exceeded:          no
# arguably gave the world Hitler and World    | Victim Model Queries:    2
# War II , so he is definitely in the Final   | BODEGA Score:            (later)
# Four .                                      | Succeed:                 no
#                                             |
# Sample: 39 ====================================================================
# Label: 1 (57.38%) --> Failed!               |
#                                             | Running Time:            0.0001411
# And it won ’ t bring down the regime which  | Query Exceeded:          no
# by its nature ensures all of these things   | Victim Model Queries:    2
# will remain a menace to the US , its allies | BODEGA Score:            (later)
# and international security as a whole .     | Succeed:                 no
#                                             |
# Sample: 40 ====================================================================
# Label: 1 (99.94%) --> Failed!               |
#                                             | Running Time:            0.0001040
#                                             | Query Exceeded:          no
# It ’ s all being done to us .               | Victim Model Queries:    2
#                                             | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 41 ====================================================================
# Label: 1 (99.67%) --> Failed!               |
#                                             | Running Time:            0.0001416
#                                             | Query Exceeded:          no
# Farrakhan Speech : ' Jews Are My Enemy ,' ' | Victim Model Queries:    2
# White Folks Are Going Down '                | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 42 ====================================================================
# Label: 0 (99.76%) --> 1 (54.31%)            |
#                                             |
#           Blind         , the      old      |
# secretary interventions . utilized largely  | Running Time:            0.0001297
#                                             | Query Exceeded:          no
# Cardinal largely utilized his secretary     | Victim Model Queries:    3
# ,        old     Blind    his to            | BODEGA Score:            (later)
#                                             | Succeed:                 yes
# to       write his interventions .          |
# Cardinal write his               the        |
#                                             |
# Sample: 43 ====================================================================
# Label: 0 (99.77%) --> Failed!               |
#                                             | Running Time:            0.0001376
# The Awans were banned from Congress ’ s     | Query Exceeded:          no
# computer network the day the letter was     | Victim Model Queries:    2
# sent , and Kiko held a briefing to convey   | BODEGA Score:            (later)
# the message to chiefs of staff for members  | Succeed:                 no
# who employed them .                         |
#                                             |
# Sample: 44 ====================================================================
# Label: 0 (89.55%) --> 1 (96.38%)            |
#                                             |
#            The video found it ’             |
# on near so is  and   .     it children      |
#                                             | Running Time:            0.0001328
# s        way to Twitter , and     it    is  | Query Exceeded:          no
# watching err to         , Twitter found ’   | Victim Model Queries:    3
#                                             | BODEGA Score:            (later)
# slightly violent ,   so err on   the side   | Succeed:                 yes
# of       caution the s  way side The it     |
#                                             |
# of      caution if watching near children . |
# violent video   if               slightly , |
#                                             |
# Sample: 45 ====================================================================
# Label: 1 (86.64%) --> 0 (98.11%)            |
#                                             |
# “ The      laws are    obsolete ,           |
# , security to   taking terms    horrible    |
#                                             |
# the laws are horrible ,   having to    do   |
# of  are  in  the      the ,”     terms “    | Running Time:            0.0002143
#                                             | Query Exceeded:          no
# with the border ,   both     in terms of    | Victim Model Queries:    3
# with in  laws   and obsolete ,  ,     of    | BODEGA Score:            (later)
#                                             | Succeed:                 yes
# security and in terms  of taking care       |
# said     he  do border of care   laws       |
#                                             |
# of     people ,” he     said .              |
# having The    .  people are  both           |
#                                             |
# Sample: 46 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0001056
#                                             | Query Exceeded:          no
# “ We thus stress the high value of          | Victim Model Queries:    2
# relationships ,” explains Lehner .          | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 47 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0001116
# The New York Times ’ Ross Douthat is among  | Query Exceeded:          no
# those who are starting to ask these kinds   | Victim Model Queries:    2
# of questions .                              | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 48 ====================================================================
# Label: 0 (99.90%) --> Failed!               |
#                                             | Running Time:            0.0001013
#                                             | Query Exceeded:          no
# “ We must not be closed to new things .     | Victim Model Queries:    2
#                                             | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 49 ====================================================================
# Label: 1 (99.98%) --> Failed!               |
#                                             |
# It ’ s as if the U . S . Army stopped to    | Running Time:            0.0002074
# interrogate every German soldier who        | Query Exceeded:          no
# crashed through the Ardennes Forest at the  | Victim Model Queries:    2
# beginning of the Battle of the Bulge in     | BODEGA Score:            (later)
# 1944 , to see if each one ’ s actions had   | Succeed:                 no
# anything to do with the German Army and     |
# Adolf Hitler ’ s war aims .                 |
#                                             |
# Sample: 50 ====================================================================
# Label: 1 (98.90%) --> Failed!               |
#                                             |
# The conversation began normally , with      | Running Time:            0.0001228
# Clinton hypocritically toeing the           | Query Exceeded:          no
# progressive line of identity politics by    | Victim Model Queries:    2
# explaining how each of the groups are       | BODEGA Score:            (later)
# different but can be managed by the same    | Succeed:                 no
# liberal movement :                          |
#                                             |
# Sample: 51 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0001111
#                                             | Query Exceeded:          no
# Looks like they ’ re already starting to    | Victim Model Queries:    2
# deploy troops at the border .               | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 52 ====================================================================
# Label: 0 (99.97%) --> Failed!               |
#                                             | Running Time:            0.0001602
# Kavanaugh then allegedly covered the woman  | Query Exceeded:          no
# ’ s mouth with his hand and attempted to    | Victim Model Queries:    2
# force himself on her , but she says she     | BODEGA Score:            (later)
# managed to free herself and bolt out of the | Succeed:                 no
# room .                                      |
#                                             |
# Sample: 53 ====================================================================
# Label: 1 (50.45%) --> 0 (99.73%)            |
#                                             | Running Time:            0.0001290
# Does it   have any precedent      in        | Query Exceeded:          no
# any  have in   it  precedent Does ?         | Victim Model Queries:    3
#                                             | BODEGA Score:            (later)
# Catholic history ?                          | Succeed:                 yes
# Catholic history                            |
#                                             |
# Sample: 54 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0001118
#                                             | Query Exceeded:          no
# Hadeed : You ’ re not answering the         | Victim Model Queries:    2
# question .                                  | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 55 ====================================================================
# Label: 1 (99.90%) --> Failed!               |
#                                             |
# He asked why “ the systematic brutality ,   |
# the widespread atrocities , the ruthless    |
# suppression of independent thought ” of the | Running Time:            0.0002363
# Soviet Union were well known in the West    | Query Exceeded:          no
# while America ’ s imperial crimes “ never   | Victim Model Queries:    2
# happened … even while [ they ] were         | BODEGA Score:            (later)
# happening , they never happened .” No Place | Succeed:                 no
# to Hide : Edwa ... Glenn Greenwald Best     |
# Price : $ 1 . 49 Buy New $ 3 . 70 ( as of   |
# 06 : 30 EDT - Details )                     |
#                                             |
# Sample: 56 ====================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             |
# ODNI spokeswoman Kellie Wade also said that | Running Time:            0.0001321
# the agency was “ working expeditiously with | Query Exceeded:          no
# our interagency partners to conduct a       | Victim Model Queries:    2
# declassification review of the documents    | BODEGA Score:            (later)
# the President has identified for            | Succeed:                 no
# declassification .”                         |
#                                             |
# Sample: 57 ====================================================================
# Label: 0 (99.96%) --> Failed!               |
# ...
#                                             | Running Time:            0.0000865
#                                             | Query Exceeded:          no
# .                                           | Victim Model Queries:    2
#                                             | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 403 ===================================================================
# Label: 1 (99.87%) --> Failed!               |
#                                             | Running Time:            0.0001490
# The outbreak of the black plague in         | Query Exceeded:          no
# Madagascar has so far killed 97 people ,    | Victim Model Queries:    2
# and doctors are warning that it will be     | BODEGA Score:            (later)
# continuing to spread and worsen , meaning   | Succeed:                 no
# no one is safe .                            |
#                                             |
# Sample: 404 ===================================================================
# Label: 0 (99.96%) --> 1 (98.50%)            |
#                                             |
# Today    Corker has nothing to    restrain  |
# restrain agenda s   from    Trump Today     | Running Time:            0.0001340
#                                             | Query Exceeded:          no
# him    from scuttling Trump ’ s             | Victim Model Queries:    3
# Corker to   him       has   ’ nothing       | BODEGA Score:            (later)
#                                             | Succeed:                 yes
# agenda    .                                 |
# scuttling .                                 |
#                                             |
# Sample: 405 ===================================================================
# Label: 1 (99.97%) --> Failed!               |
#                                             |
# Do not all those ignorant critics of AL     |
# know that the Latin text employs the phrase | Running Time:            0.0001676
# “ obiectivum exemplar ,” which , translated | Query Exceeded:          no
# literally into English is “ objective       | Victim Model Queries:    2
# exemplar .” They declare triumphantly : “   | BODEGA Score:            (later)
# The Latin term exemplar does not mean an    | Succeed:                 no
# unattainable ideal , it specifically means  |
# a pattern or model to follow .”             |
#                                             |
# Sample: 406 ===================================================================
# Label: 0 (99.97%) --> 1 (78.83%)            |
#                                             |
# “ The blessing expresses that one is        |
#   end article  expresses he   At  blessings |
#                                             |
# welcomed by  one    '  s partner and        |
# welcomed The pastor of a that    individual |
#                                             |
# by        God .” At    the end of his       |
# interview 3   is about “   by  .” to        |
#                                             |
# article , he       adds           a         |
# link    a openness adds idea . as God       |
#                                             | Running Time:            0.0001700
# link    to  another report about            | Query Exceeded:          no
# showing his another the    blessing         | Victim Model Queries:    3
#                                             | BODEGA Score:            (later)
# Cardinal Reinhard Marx '  s recent 3        | Succeed:                 yes
# report   Reinhard      by s in     cases    |
#                                             |
# February interview showing his openness to  |
# s        of        '       and one      ,   |
#                                             |
# the     idea     of blessings of            |
# decided February '  his       Marx          |
#                                             |
# homosexual couples in  individual cases  as |
# homosexual         one to         recent by |
#                                             |
# decided by  a        pastor  .              |
# of      the Cardinal partner couples        |
#                                             |
# Sample: 407 ===================================================================
# Label: 1 (95.95%) --> 0 (82.32%)            |
#                                             |
# The October Synod      is     yet another   |
#     of      exploiting Church and .         |
#                                             |
# example  of      Church leaders exploiting  |
# Catholic October is     for     personal    | Running Time:            0.0001357
#                                             | Query Exceeded:          no
# Catholic youth for their own     personal   | Victim Model Queries:    3
# their    youth The own   another example    | BODEGA Score:            (later)
#                                             | Succeed:                 yes
# power         agenda  and     selfish       |
# power selfish leaders motives yet           |
#                                             |
# motives .                                   |
# agenda  Synod                               |
#                                             |
# Sample: 408 ===================================================================
# Label: 0 (99.85%) --> Failed!               |
#                                             | Running Time:            0.0001268
# Meanwhile , a third caravan of migrants ,   | Query Exceeded:          no
# this time from El Salvador , has reportedly | Victim Model Queries:    2
# already crossed into Mexico .               | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 409 ===================================================================
# Label: 0 (99.98%) --> Failed!               |
#                                             |
# The Italian Catholic daily La Nuova Bussola |
# Quotidiana reports that not only did the    | Running Time:            0.0001514
# pope see a letter from victims , but that   | Query Exceeded:          no
# the CDF , under Muller , “ had already      | Victim Model Queries:    2
# conducted an preliminary investigation into | BODEGA Score:            (later)
# Barros and the other bishops close to       | Succeed:                 no
# Karadima which had led to the decision to   |
# relieve them of their duties .”             |
#                                             |
# Sample: 410 ===================================================================
# Label: 0 (99.98%) --> 1 (77.20%)            |
#                                             |
# In  May     of   this year ,       Twitter  |
# the forcing Omar year user Gilmore In       |
#                                             | Running Time:            0.0001705
# user    John Gilmore dug    up   the  six   | Query Exceeded:          no
# herself May  ,       defend John year six   | Victim Model Queries:    3
#                                             | BODEGA Score:            (later)
# -       year -  old tweet , forcing Omar    | Succeed:                 yes
# Twitter .    up dug -     - this    tweet   |
#                                             |
# to  defend herself .                        |
# old ,      of      to                       |
#                                             |
# Sample: 411 ===================================================================
# Label: 1 (93.49%) --> Failed!               |
#                                             |
# What scandalizes believers , and even some  | Running Time:            0.0001915
# fellow bishops , is not only your having    | Query Exceeded:          no
# appointed such men to be shepherds of the   | Victim Model Queries:    2
# Church , but that you also seem silent in   | BODEGA Score:            (later)
# the face of their teaching and pastoral     | Succeed:                 no
# practice ….                                 |
#                                             |
# Sample: 412 ===================================================================
# Label: 0 (99.98%) --> Failed!               |
#                                             | Running Time:            0.0001218
#                                             | Query Exceeded:          no
# It ’ s hardest when it ’ s strongest .      | Victim Model Queries:    2
#                                             | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 413 ===================================================================
# Label: 0 (97.86%) --> Failed!               |
#                                             |
# Earlier this month , the U . S . Department |
# of Housing and Urban Development announced  | Running Time:            0.0002573
# it would provide $ 1 . 5 billion to help    | Query Exceeded:          no
# rebuild housing in Puerto Rico after        | Victim Model Queries:    2
# devastation from both Maria and Hurricane   | BODEGA Score:            (later)
# Irma , which skirted the island a couple of | Succeed:                 no
# weeks before , through HUD ' s Community    |
# Development Block Grant Disaster Recovery   |
# program .                                   |
#                                             |
# Sample: 414 ===================================================================
# Label: 0 (99.29%) --> Failed!               |
#                                             |
# This reputation was cemented during his     | Running Time:            0.0001581
# work as the peritus , the theological       | Query Exceeded:          no
# advisor , of one of the Council ’ s most    | Victim Model Queries:    2
# influential of the bishops of the           | BODEGA Score:            (later)
# progressive camp , Cardinal Josef Frings of | Succeed:                 no
# Cologne .                                   |
#                                             |
# Sample: 415 ===================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0001323
# The CAO and [ sergeant - at - arms ] worked | Query Exceeded:          no
# with the Chairman to account for his        | Victim Model Queries:    2
# inventory , including the one server .      | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# Sample: 416 ===================================================================
# Label: 0 (99.99%) --> Failed!               |
#                                             | Running Time:            0.0000927
#                                             | Query Exceeded:          no
# Email *                                     | Victim Model Queries:    2
#                                             | BODEGA Score:            (later)
#                                             | Succeed:                 no
#                                             |
# +=========================================+
# |                 Summary                 |
# +=========================================+
# | Total Attacked Instances:  | 416        |
# | Successful Instances:      | 74         |
# | Attack Success Rate:       | 0.17788    |
# | Avg. Running Time:         | 0.00016861 |
# | Total Query Exceeded:      | 0          |
# | Avg. Victim Model Queries: | 2.1779     |
# | Avg. BODEGA Score:         | nan        |
# +=========================================+
# Victim caching: saving...
# Aligning sentences...
# Using model LAMBO-UD_English-EWT
# 100%|██████████| 1.89k/1.89k [00:00<00:00, 5.29MB/s]
# 100%|██████████| 2.84M/2.84M [00:01<00:00, 2.56MB/s]
# 100%|██████████| 373k/373k [00:00<00:00, 579kB/s]
# Computing semantic score...
# Computing BODEGA score...
# Subset size: 416
# Success score: 0.1778846153846154
# Semantic score: 0.40792747828606013
# Character score: 0.3001644500157
# BODEGA score: 0.023084385477252653
# Queries per example: 2.1778846153846154
# Total attack time: 15.91714334487915
# Time per example: 0.03826236380980565
# Total evaluation time: 10.89548373222351
# -
# Bodega metrics saved to /content/BODEGA/outputs/results_PR2_False_custom_BERT.txt
# Submission file saved to /content/BODEGA/outputs/submission_PR2_False_custom_BERT.tsv

# %% [markdown]
# Your output should look like this.
# The custom attack has a very low BODEGA score, suggesting that the attack was not very successful (low success rate and low preservation of meaning).
#
# VictimBERT on PR2:
# ```
# Subset size: 416
# Success score: 0.1778846153846154
# Semantic score: 0.40792732766351186
# Character score: 0.3001644500157
# BODEGA score: 0.02308437726605881
# Queries per example: 2.1778846153846154
# Total attack time: 19.421820878982544
# Time per example: 0.04668706942063112
# Total evaluation time: 10.617336988449097
# ```

# %% [markdown]
# ## Submission Files

# %% [markdown]
# Whenever you run an attack on a dataset, a submission_task.tsv file will be saved to your outputs directory. At the end of the test phase, you will need to submit your final attack's submission files to the shared task organisers for evaluation (1 for each dataset * num_victim_classifiers).
#
# The submission file contains 4 pieces of information per attacked text:
# 1. was the attack successful
# 2. number of queries to victim model used to generate the adversarial sample
# 3. the original text
# 4. the adversarial text (or ATTACK_UNSUCCESSFUL if unsuccessful)

# %% [markdown]
# ## Final tips:
#
# ### Using a subset of eval dataset
# Testing your attack on the entire eval dataset can take a while. To speed things up, you can test on the first n samples of the dataset, by setting `using_first_n_samples` to `True`.
#
# ### Running pre-implemented attacks
#
# BODEGA supports a number of pre-existing attacks. Trying these might be useful if you want to:
# - compare your performance with existing methods (also reported in the [BODEGA preprint](https://arxiv.org/abs/2303.08032))
# - get inspiration from observing their substitutions
#
# To use an existing attack requires only two changes to the code above:
# 1. set `using_custom_attacker` to `False`
# 2. set `attack` to the name of a supported attack
# (`PWWS`, `SCPN`, `TextFooler`, `DeepWordBug`, `GAN`, `Genetic`, `PSO`, `BERTattack` or`BAE`)
#
# Note that using `BAE` or `TextFooler` will require you to install additional dependencies since they rely on tensorflow:
#
# - tensorflow >= 2.0.0
# - tensorflow_hub
#
# https://openattack.readthedocs.io/en/latest/quickstart/installation.html
